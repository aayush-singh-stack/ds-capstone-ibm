# %% [markdown]
# This is a Jupyter Notebook for IBM's Data Science Capstone Project

# %%
import pandas as pd
import numpy as np
print("Hello to the Capstone Project")
# Out:
# Hello to the Capstone Project
